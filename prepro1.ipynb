# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('diabetes_indian.csv')

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
df['BMI'][148]
# Out:
# 33.7

# %%
df['Outcome'].value_counts().plot(kind = 'bar')
plt.show()

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df[['Pregnancies','BMI']]
# Out:
#      Pregnancies   BMI
# 0              6  33.6
# 1              1  26.6
# 2              8  23.3
# 3              1  28.1
# 4              0  43.1
# ..           ...   ...
# 763           10  32.9
# 764            2  36.8
# 765            5  26.2
# 766            1  30.1
# 767            1  30.4
#
# [768 rows x 2 columns]

# %%
df['BMI'] > 25
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 763     True
# 764     True
# 765     True
# 766     True
# 767     True
# Name: BMI, Length: 768, dtype: bool

# %%
df[df['BMI'] > 25]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 3                       0.167   21        0
# 4                       2.288   33        1
# 5                       0.201   30        0
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [645 rows x 9 columns]

# %%
df1 = df[(df['BMI'] > 25) & (df['Age'] < 30)]

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df1.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   317.000000  317.000000     317.000000     317.000000  317.000000
# mean      1.940063  117.100946      67.482650      24.514196   94.630915
# std       1.748291   29.459625      16.400173      14.495655  114.417703
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   95.000000      60.000000      17.000000    0.000000
# 50%       2.000000  113.000000      68.000000      27.000000   70.000000
# 75%       3.000000  134.000000      78.000000      35.000000  135.000000
# max      10.000000  199.000000     110.000000      63.000000  680.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  317.000000                317.000000  317.000000  317.000000
# mean    34.176341                  0.474596   24.529968    0.261830
# std      6.553140                  0.322734    2.577265    0.440325
# min     25.100000                  0.078000   21.000000    0.000000
# 25%     29.000000                  0.256000   22.000000    0.000000
# 50%     33.200000                  0.400000   24.000000    0.000000
# 75%     37.800000                  0.607000   27.000000    1.000000
# max     67.100000                  2.420000   29.000000    1.000000

# %%
df.hist(figsize = (20,20))
plt.show()

# %%
plt.figure(figsize = (20,10))
plt.scatter(df['Glucose'],df['BMI'])
plt.show()

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
df.corr()[df.corr() > 0.4]
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000       NaN            NaN            NaN
# Glucose                           NaN  1.000000            NaN            NaN
# BloodPressure                     NaN       NaN            1.0            NaN
# SkinThickness                     NaN       NaN            NaN       1.000000
# Insulin                           NaN       NaN            NaN       0.436783
# BMI                               NaN       NaN            NaN            NaN
# DiabetesPedigreeFunction          NaN       NaN            NaN            NaN
# Age                          0.544341       NaN            NaN            NaN
# Outcome                           NaN  0.466581            NaN            NaN
#
#                            Insulin  BMI  DiabetesPedigreeFunction       Age  \
# Pregnancies                    NaN  NaN                       NaN  0.544341
# Glucose                        NaN  NaN                       NaN       NaN
# BloodPressure                  NaN  NaN                       NaN       NaN
# SkinThickness             0.436783  NaN                       NaN       NaN
# Insulin                   1.000000  NaN                       NaN       NaN
# BMI                            NaN  1.0                       NaN       NaN
# DiabetesPedigreeFunction       NaN  NaN                       1.0       NaN
# Age                            NaN  NaN                       NaN  1.000000
# Outcome                        NaN  NaN                       NaN       NaN
#
#                            Outcome
# Pregnancies                    NaN
# Glucose                   0.466581
# BloodPressure                  NaN
# SkinThickness                  NaN
# Insulin                        NaN
# BMI                            NaN
# DiabetesPedigreeFunction       NaN
# Age                            NaN
# Outcome                   1.000000
